# %%
from bigbang.analysis.datatracker import *

# %%
df = draft_authors_from_working_group("dnsop")

# %%
df
# Out:
#                                 email                name submission_date  \
# 0                 pwouters@redhat.com        Paul Wouters      2016-02-18
# 1                 pwouters@redhat.com        Paul Wouters      2016-02-22
# 2                      jabley@dyn.com           Joe Abley      2016-02-22
# 3                    sara@sinodun.com      Sara Dickinson      2016-02-22
# 4                         ray@isc.org          Ray Bellis      2016-02-22
# ..                                ...                 ...             ...
# 378             olafur@cloudflare.com  Olafur Gudmundsson      2023-05-09
# 379                       pk@DENIC.DE          Peter Koch      2023-06-07
# 380             matt.larson@icann.org         Matt Larson      2023-06-07
# 381            paul.hoffman@icann.org        Paul Hoffman      2023-06-07
# 382  peter.thomassen@securesystems.de     Peter Thomassen      2023-08-01
#
#                                              draft_uri  \
# ...

# %%
df.groupby("affiliation").count().sort_values("email", ascending=False).head(10)
# Out:
#                              email  name  submission_date  draft_uri  title  \
# affiliation
# ICANN                           34    34               34         34     34
# Google                          16    16               16         16     16
# Internet Systems Consortium     16    16               16         16     16
# Verisign                        15    15               15         15     15
# Salesforce                      13    13               13         13     13
# ISC                             10    10               10         10     10
# Akamai Technologies              8     8                8          8      8
# USC/ISI                          8     8                8          8      8
# NLnet Labs                       7     7                7          7      7
# Cloudflare                       6     6                6          6      6
#
#                              country  errors  raw_text
# affiliation
# ...
