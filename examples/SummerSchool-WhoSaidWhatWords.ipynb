# %%
from bigbang.archive import Archive
from bigbang.archive import load as load_archive
import bigbang.graph as graph
import networkx as nx
import os
import pandas as pd

# %%
icann_path = "../archives/http:/mm.icann.org/pipermail"
ncuc_path = "../archives/http:/lists.ncuc.org/pipermail"

paths = [os.path.join(icann_path,"ipc-gnso.csv"),
        os.path.join(icann_path,"wp4.csv"),
        os.path.join(icann_path,"alac.csv"),
        os.path.join(icann_path,"gnso-rds-pdp-wg.csv"),
        os.path.join(icann_path,"accountability-cross-community.csv"),
        os.path.join(icann_path,"cc-humanrights.csv"),
        os.path.join(ncuc_path,"ncuc-discuss.csv")]

datas = [load_archive(path).data for path in paths]
         
arx = Archive(pd.concat(datas))
# Out:
# /home/sb/projects/nllz-bigbang/bigbang/bigbang/archive.py:73: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   self.data.sort(columns='Date', inplace=True)

# %%
word = "h"

data = arx.data

data[word] = data['Body'].apply(lambda x: x.count(word) if x else 0)

# %%
data.groupby('From').sum()
# Out:
#                                                     rights
# From
# AAikman at lrrc.com (Aikman-Scalese, Anne)               0
# AAikman at lrrlaw.com (Aikman-Scalese, Anne)            13
# Alex_Deacon at mpaa.org (Deacon, Alex)                   4
# Amadeu at nominalia.com (Amadeu Abril i Abril)           3
# Avri at ACM.ORG (Avri Doria)                             0
# BWinterfeldt at mayerbrown.com (Winterfeldt, Br...       0
# Becky.Burr at neustar.biz (Burr, Becky)                187
# Beth.Allegretti at fox.com (Beth Allegretti)             0
# Bradley.Silver at timewarner.com (Silver, Bradley)      50
# Brenbe at CONSUMER.ORG (Brendler, Beau)                  8
# Brett.Schaefer at heritage.org (Schaefer, Brett)        70
# Bruce at barelyadequate.info (Bruce Young)               0
# Bruce.Tonkin at melbourneit.com.au (Bruce Tonkin)       95
# CCHIU at ACLU.ORG (Chris Chiu)                           4
# CCHIU at aclu.org (Chris Chiu)                           7
# CHagstrom at lb.com (Hagstrom, Christopher)              0
# CLackert at reedsmith.com (Lackert, Clark W.)            1
# Camino.MANJON at ec.europa.eu (Camino.MANJON at...     141
# Carlos.Souza at FGV.BR (Carlos Affonso Pereira ...       0
# DFares at 21cf.com (Fares, David)                        0
# DNSO.Secretariat at dnso.org (DNSO Secretariat)          1
# DSimon at SONOSKY.COM (Donald Simon)                     1
# DannyYounger at cs.com (DannyYounger at cs.com)          4
# David.Taylor at hoganlovells.com (Taylor, David)         0
# Dixie at GLOBAL-PARTNERS.CO.UK (Dixie Hawtin)            0
# Donna.Austin at neustar.biz (Austin, Donna)              0
# Elisabeth.Porteneuve at cetp.ipsl.fr (Elisabeth...       5
# Ellen.M.Blackler at disney.com (Blackler, Ellen...       8
# FVayra at perkinscoie.com (Vayra, Fabricio  (Pe...       3
# FinPet at erst.dk (Finn Petersen)                        4
# ...                                                    ...
# wendy at seltzer.com (Wendy Seltzer)                     9
# wgondwe at CC.AC.MW (Walu G. Gondwe)                     0
# william.drake at GRADUATEINSTITUTE.CH (Drake Wi...       0
# william.drake at GRADUATEINSTITUTE.CH (William ...      53
# william.drake at UZH.CH (William Drake)                 49
# william.drake at uzh.ch (William Drake)                 82
# willie.currie at gmail.com (william currie)            145
# wilson at isoc.ug (Wilson Abigaba)                       0
# wisdom.dk at gmail.com (Wisdom Donkor)                   4
# wisdom.stoic at gmail.com (Rahul Sharma)                57
# wjdrake at gmail.com (William Drake)                   146
# wolf-ulrich.knoben at t-online.de (WUKnoben)             1
# wolf.ludwig at comunica-ch.net (Wolf Ludwig)             1
# wolfgang.kleinwaechter at MEDIENKOMM.UNI-HALLE....       0
# wolfgang.kleinwaechter at medienkomm.uni-halle....      30
# wpilimon at dfp-interactive.com (=?iso-8859-1?Q...       0
# wsaqaf at gmail.com (Walid AL-SAQAF)                     7
# wsis at modirian.net (Modirian)                          3
# xavier.calvez at icann.org (Xavier J. Calvez)            1
# yakmutd at yahoo.com (Daniel Yakmut)                     0
# yameogoben at yahoo.fr (Bernard YAMEOGO)                 0
# yjpark at MYEPARK.COM (Y J Park)                         0
# yjpark at MYEPARK.COM (YJ Park)                          2
# yjpark at myepark.com (YJ Park)                          3
# yjpark21 at GMAIL.COM (YJ Park)                          0
# yjpark21 at GMAIL.COM (Youn Jung Park)                   0
# zainsyed45 at gmail.com (Zain Khan, CMC)                 0
# zakirbinrehman at yahoo.com (Zakir Syed)                 0
# zalnieriute at gmail.com (zalnieriute .)               166
# zbone72 at yahoo.com (Brett Spears)                      0
#
# [1166 rows x 1 columns]
