# %%
# %matplotlib inline
from bigbang.archive import Archive
from bigbang import repo_loader;
from bigbang.git_repo import GitRepo;
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import bigbang.entity_resolution

# %%
repo = repo_loader.get_repo("bigbang")
full_info = repo.commit_data;
# Out:
# Checking if cached
# Running Entity Resolution on bigbang

# %%
import networkx as nx;

# %%
G = nx.Graph()

def add_to_graph(r): # Adds info from row to graph
    author = bigbang.entity_resolution.name_for_id(r["Person-ID"])
    files = r["Touched File"]
    for f in files:
        if G.has_edge(author, f):
            G[author][f]['weight'] += 1
        else:
            G.add_edge(author, f, weight = 1)
            G.node[author]["type"] = 'author'
            G.node[f]["type"] = 'file'


    
   
a = full_info.apply(add_to_graph, axis=1) # Dummy to make it not print

for u,v in G.edges():
    G[u][v]['weight'] *= 3.0
    G[u][v]['weight'] = G.degree(u)
    print(G.degree[u])

widths = [G[u][v]['weight']/20.0 for u, v in G.edges()]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-c02cce999dc8> in <module>()
#      19 for u,v in G.edges():
#      20     G[u][v]['weight'] *= 3.0
# ---> 21     G[u][v]['weight'] = G.degree[u]
#      22     print(G.degree[u])
#      23
#
# TypeError: 'instancemethod' object has no attribute '__getitem__'

# %%
#nx.draw(G)
plt.figure(1,figsize=(15, 15))
pos = nx.spring_layout(G, k = 0.6, iterations = 20)
nx.draw_networkx_nodes(G, pos, nodelist = [node[0] for node in G.nodes(data=True) if node[1]["type"] == 'author'], node_size=750, node_color = 'r')
nx.draw_networkx_nodes(G, pos, nodelist = [node[0] for node in G.nodes(data=True) if node[1]["type"] == 'file'], node_color = 'b')
nx.draw_networkx_edges(G, pos, width=widths, edge_color = 'g', alpha = 0.8)
#nx.draw_networkx_edges(G, pos, width=widths, edge_color = widths)
nx.draw_networkx_labels(G, pos);

# %%
print(bigbang.entity_resolution.namesID)
# Out:
# {u'DAVE LESTER': 11, u'JESSICA XU': 2, u'SEBASTIAN BENTHALL': 1, u'RAJ AGRAWAL': 7, u'DAVID WINSLOW': 5, u'JACK005': 8, u'KI DEUK KIM': 6, u'SHREYAS': 10, u'SPIROS ELIOPOULOS': 12, u'VENKATA POREDDY': 3, u'NICK DOTY': 13, u'SB': 1, u'TEERANAN': 9, u'ARYAN FALAHATPISHEH': 4}
