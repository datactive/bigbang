# %% [markdown]
# This notebook shows how BigBang can be used to display a graph of interactions in the mailing list over some period of time.
#
# First we'll make the I Python notebook display computed visualizations inline.

# %%
# %matplotlib inline

# %% [markdown]
# Next we'll import dependencies.

# %%
from bigbang.archive import Archive
import bigbang.parse as parse
import bigbang.analysis.graph as graph
import bigbang.ingress.mailman as mailman
import bigbang.analysis.process as process
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd
from pprint import pprint as pp
import pytz

# %% [markdown]
# Now we will use BigBang to process mailing list archives we've already downloaded.
#
# Note that you can load an Archive that you have stored locally in a .csv file just by using its shortened *name*. You can also still include full URL's if you haven't downloaded the data yet, or you aren't sure.

# %%
urls = [
    "ipython-dev",
    "hot",
    "scipy-user",
    "https://lists.wikimedia.org/pipermail/gendergap/",
    "ipython-user",
]

archives = [Archive(url, archive_dir="../archives") for url in urls]

# %% [markdown]
# Here we will set the window for analysis. By default, November 2011.

# %%
date_from = pd.datetime(2011, 11, 1, tzinfo=pytz.utc)
date_to = pd.datetime(2011, 12, 1, tzinfo=pytz.utc)

# %% [markdown]
# This is a helper function to select messages from a dataframe that fall within a certain range of dates.

# %%
def filter_by_date(df, d_from, d_to):
    return df[(df["Date"] > d_from) & (df["Date"] < d_to)]

# %% [markdown]
# A function for drawing interaction graphs.
#
# *TODO: Move this into the library code*

# %%
def draw_interaction_graph(ig):
    # pdig = nx.to_pydot(ig)
    # pdig.set_overlap('False')

    pos = nx.graphviz_layout(ig, prog="neato")
    node_size = [data["sent"] * 40 for name, data in ig.nodes(data=True)]

    nx.draw(
        ig,
        pos,
        node_size=node_size,
        node_color="w",
        alpha=0.4,
        font_size=18,
        font_weight="bold",
    )

    # edge width is proportional to replies sent
    edgewidth = [d["weight"] for (u, v, d) in ig.edges(data=True)]

    # overlay edges with width based on weight
    nx.draw_networkx_edges(ig, pos, alpha=0.5, width=edgewidth, edge_color="r")

# %% [markdown]
# Now we'll use BigBang's graph processing methods to turn the processed messages into a graph of interactions.

# %%
plt.figure(230, figsize=(12.5, 7.5))
for i, arx in enumerate(archives):
    plt.subplot(230 + i)  # create a subplot keyed to the index of this ml
    df = arx.data
    dff = filter_by_date(df, date_from, date_to)
    ig = graph.messages_to_interaction_graph(dff)
    print(urls[i])
    print(nx.degree_assortativity_coefficient(ig))
    draw_interaction_graph(ig)

plt.show()
# Out:
# ipython-dev
# -0.442541410433
# hot
# -0.204913127515
# scipy-user
# -0.131527105478
# https://lists.wikimedia.org/pipermail/gendergap/
# -0.292926048744
# ipython-user
# -0.6545197369

# %%
dfs = [filter_by_date(arx.data, date_from, date_to) for arx in archives]

bdf = pd.concat(dfs)

# RG = graph.messages_to_reply_graph(messages)

IG = graph.messages_to_interaction_graph(bdf)

pdig = nx.to_pydot(IG)

pdig.set_overlap("False")

# %% [markdown]
# Lastly, we use NetworkX's built in compatibility with Matplotlib to visualize the graph.

# %%
plt.figure(figsize=(12.5, 7.5))

draw_interaction_graph(IG)

plt.show()

# %%
nx.write_edgelist(IG, "ig-edges.txt", delimiter="\t")

# %%
nx.write_gexf(IG, "all.gexf")

# %%
arx = archives[0]

# %%
arx.data
# Out:
#                                                                                                                    From  \
# Message-ID
# <3E9DE124.8080309@colorado.edu>                                                    fperez@colorado.edu (Fernando Perez)
# <3E9DE124.8080309@colorado.edu>                                                 fperez at colorado.edu (Fernando Perez)
# <3E9E4094.7030802@colorado.edu>                                                    fperez@colorado.edu (Fernando Perez)
# <3E9E4094.7030802@colorado.edu>                                                 fperez at colorado.edu (Fernando Perez)
# <000c01c304ee$3cb79e60$e901340a@cyberhigh.fcoe.k12.ca.us>                              cdodt@fcoe.k12.ca.us (Cory Dodt)
# <000c01c304ee$3cb79e60$e901340a@cyberhigh.fcoe.k12.ca.us>                           cdodt at fcoe.k12.ca.us (Cory Dodt)
# <3E9EC1CA.3060800@colorado.edu>                                                    fperez@colorado.edu (Fernando Perez)
# <3E9EC1CA.3060800@colorado.edu>                                                 fperez at colorado.edu (Fernando Perez)
# <3E9EF5E3.8080100@colorado.edu>                                                    fperez@colorado.edu (Fernando Perez)
# <3E9EF5E3.8080100@colorado.edu>                                                 fperez at colorado.edu (Fernando Perez)
# <3E9EFC95.7040309@colorado.edu>                                                 fperez at colorado.edu (Fernando Perez)
# <3E9EFC95.7040309@colorado.edu>                                                    fperez@colorado.edu (Fernando Perez)
# <3E9F3B79.7070005@colorado.edu>                                                 fperez at colorado.edu (Fernando Perez)
# <3E9F3B79.7070005@colorado.edu>                                                    fperez@colorado.edu (Fernando Perez)
# <3E9F3D9B.8040807@colorado.edu>                                                    fperez@colorado.edu (Fernando Perez)
# <3E9F3D9B.8040807@colorado.edu>                                                 fperez at colorado.edu (Fernando Perez)
# <200304291817.05898.Kasper.Souren@ircam.fr>                                   Kasper.Souren at ircam.fr (Kasper Souren)
# <200304291817.05898.Kasper.Souren@ircam.fr>                                      Kasper.Souren@ircam.fr (Kasper Souren)
# <3EAEF194.5030709@colorado.edu>                                                    fperez@colorado.edu (Fernando Perez)
# <3EAEF194.5030709@colorado.edu>                                                 fperez at colorado.edu (Fernando Perez)
# <200304292248.10994.Kasper.Souren@ircam.fr>                                      Kasper.Souren@ircam.fr (Kasper Souren)
# <200304292248.10994.Kasper.Souren@ircam.fr>                                   Kasper.Souren at ircam.fr (Kasper Souren)
# <CB0365D517B7D611B5E100508B9498B6022A9B50@erlh904a.med.siemens.de>    christopher.drexler@siemens.com (Drexler Chris...
# <CB0365D517B7D611B5E100508B9498B6022A9B50@erlh904a.med.siemens.de>    christopher.drexler at siemens.com (Drexler Ch...
# <200305121234.h4CCYmXo027167@wren.cs.unc.edu>                                               gb@cs.unc.edu (Gary Bishop)
# <200305121234.h4CCYmXo027167@wren.cs.unc.edu>                                            gb at cs.unc.edu (Gary Bishop)
# <3EC143D7.8050907@colorado.edu>                                                 fperez at colorado.edu (Fernando Perez)
# <3EC143D7.8050907@colorado.edu>                                                    fperez@colorado.edu (Fernando Perez)
# <200305171149.h4HBneXo024735@wren.cs.unc.edu>                                            gb at cs.unc.edu (Gary Bishop)
# <200305171149.h4HBneXo024735@wren.cs.unc.edu>                                               gb@cs.unc.edu (Gary Bishop)
# ...                                                                                                                 ...
# <CAGA_dmj2Mbf7wydpTX6wD=x7VmkBE+6efWC=5jC4pSPiQy0CnQ@mail.gmail.com>    maximilian.albert@gmail.... (Maximilian Albert)
# <CACejjWychJZv_QXsOx3iQ6CETt_hFXQVRW1eT3dYizjPVW8HSQ@mail.gmail.com>          nick.bollweg@gmail.... (Nicholas Bollweg)
# <CAAusYCjPPDJvzhBazUk7kibW_OqeRVHNS2OykshHt+UOtzJYsw@mail.gmail.com>                  doug.blank@gmail.... (Doug Blank)
# <CADK4v1hPRXYLHucdNFLgN4U_LTbyfmb=+MEU6qrNwnmF9g9TiA@mail.gmail.com>  paad.ruslan.korniichuk@gmail.... (Ruslan Korni...
# <095EA2AD-DC8B-4A0D-A8F3-61C2BD11B635@gmail.com>                      bussonniermatthias@gmail.... (Matthias Bussonn...
# <CACfEFw-DvqgS90by+kjB1AB20AU102=6PvZBzrqK20cT8j2r0Q@mail.gmail.com>                  wes.turner@gmail.... (Wes Turner)
# <D623C3FB-430A-42C7-8E2F-E7EDF7605EF2@gmail.com>                      bussonniermatthias@gmail.... (Matthias Bussonn...
# <6CAE1ADC-853E-47CC-A5F4-AD43DEF33FB6@gmail.com>                      bussonniermatthias@gmail.... (Matthias Bussonn...
# <CACfEFw9ryXo-0j3UzwmwHPfLriWqT2OMqGOdsrqptDSSUyB7ew@mail.gmail.com>                  wes.turner@gmail.... (Wes Turner)
# <551498E2.3060207@student.american.edu>                                           jg3705a@student.american.... (Justin)
# <CAOvn4qjSAYqZjy0uR6O4qMb3vY1VoOmR-rBVSEJ30TjsP==MAg@mail.gmail.com>                  takowl@gmail.... (Thomas Kluyver)
# <CADK4v1gDrJJQ+8gYA+biJuUpXnvXLJwfFjrsVMrwouDfsa7i3A@mail.gmail.com>  paad.ruslan.korniichuk@gmail.... (Ruslan Korni...
# <5515689A.50509@student.american.edu>                                             jg3705a@student.american.... (Justin)
# <55156CBC.6020908@student.american.edu>                                           jg3705a@student.american.... (Justin)
# <55160425.6070309@student.american.edu>                                           jg3705a@student.american.... (Justin)
# <CAH+mRR2OHcPt2ZCx3E5oBfX+suRjcbRhfrM1meqSadB2HDpUyQ@mail.gmail.com>  damianavila@gmail.... (=?UTF-8?Q?Dami=C3=A1n_A...
# <CAKxBDU_e6J5h2WAtEPCax+_gn5B_zk6oDmrhat1mPZFpUUfkNA@mail.gmail.com>                yanghatespam@gmail.... (Yang Zhang)
# <CAGA_dmgWUVZNThwRL=w8yo+Ke7xgoV2N7h1oFqNLXE9-n2xVUQ@mail.gmail.com>    maximilian.albert@gmail.... (Maximilian Albert)
# <CAHAreOqyPxmA4kMiVxzBMH-fQPvx_Or-_dzB7nJuMbmdSy86Lg@mail.gmail.com>              fperez.net@gmail.... (Fernando Perez)
# <CAHNn8BUQJu4iD71whEQuQAfk0=oCjrcwcR81ANoAGyO4ZYwUjA@mail.gmail.com>                       benjaminrk@gmail.... (MinRK)
# <CAGA_dmgqF_uM3yUNSF3o4YTwa7f0w58mqOuM_+Y=TihJtO-iFw@mail.gmail.com>    maximilian.albert@gmail.... (Maximilian Albert)
# <CAHAreOq_DrcmuTQ=a2Yy3Ar=KGasMONDzB=zxP384q1sQjqeyA@mail.gmail.com>              fperez.net@gmail.... (Fernando Perez)
# <CAHAreOoT+0MD9eCfrpcW=iOj93JCVQeKjZ2TAQjzr8fOiMsVLw@mail.gmail.com>              fperez.net@gmail.... (Fernando Perez)
# <CAHAreOoj7+62Qw3z4mnKuESyfxonCoJt6QeLgt-HZLMmiDzE+w@mail.gmail.com>              fperez.net@gmail.... (Fernando Perez)
# <CAH4pYpTnB8SOtqu-tDXmrravfVvzzcaagTGks=jWHXHrK1Nipw@mail.gmail.com>                ellisonbg@gmail.... (Brian Granger)
# <CA+tbMaVCT5vN8kTEh64THqt9YcJWFuzDh=D-DMckwJvCe-pF9g@mail.gmail.com>                     rgbkrk@gmail.... (Kyle Kelley)
# <CAH+mRR2B+QRqPxk8cZRCG7p6tFmRUWdCiWPMe+SkxEtwec6Jhg@mail.gmail.com>  damianavila@gmail.... (=?UTF-8?Q?Dami=C3=A1n_A...
# <CANJQusWnqvjA+Jk-S6hF0Eo64GodkXPD80ne8dssW=L3g8jS+w@mail.gmail.com>  bussonniermatthias@gmail.... (Matthias Bussonn...
# <CALUXcBwNPLP-_ZndrHtDQtJ4fBuBt-Uo1m2OFhUH_+zhZfQuNA@mail.gmail.com>         jhamrick@berkeley.... (Jessica B. Hamrick)
# <CACejjWwWdJZ+NjVtn+Ao2yJCTvh+32oNEkLBwWW6Cyw+gYJSSA@mail.gmail.com>          nick.bollweg@gmail.... (Nicholas Bollweg)
#
#                                                                                                                 Subject  \
# Message-ID
# <3E9DE124.8080309@colorado.edu>                                            [IPython-dev] Mailing lists indexed at gmane
# <3E9DE124.8080309@colorado.edu>                                            [IPython-dev] Mailing lists indexed at gmane
# <3E9E4094.7030802@colorado.edu>                                       [IPython-dev] Re: Refactoring of bdist_wininst...
# <3E9E4094.7030802@colorado.edu>                                       [IPython-dev] Re: Refactoring of bdist_wininst...
# <000c01c304ee$3cb79e60$e901340a@cyberhigh.fcoe.k12.ca.us>             [IPython-dev] RE: Refactoring of bdist_wininst...
# <000c01c304ee$3cb79e60$e901340a@cyberhigh.fcoe.k12.ca.us>             [IPython-dev] RE: Refactoring of bdist_wininst...
# <3E9EC1CA.3060800@colorado.edu>                                       [IPython-dev] RE: Refactoring of bdist_wininst...
# <3E9EC1CA.3060800@colorado.edu>                                       [IPython-dev] RE: Refactoring of bdist_wininst...
# <3E9EF5E3.8080100@colorado.edu>                                       [IPython-dev] [Fwd: [ANN] A new IPython is out...
# <3E9EF5E3.8080100@colorado.edu>                                       [IPython-dev] [Fwd: [ANN] A new IPython is out...
# <3E9EFC95.7040309@colorado.edu>                                                            [IPython-dev] ToDo for 0.4.0
# <3E9EFC95.7040309@colorado.edu>                                                            [IPython-dev] ToDo for 0.4.0
# <3E9F3B79.7070005@colorado.edu>                                               [IPython-dev] New bug tracker for IPython
# <3E9F3B79.7070005@colorado.edu>                                               [IPython-dev] New bug tracker for IPython
# <3E9F3D9B.8040807@colorado.edu>                                                    [IPython-dev] Re: iPython on Windows
# <3E9F3D9B.8040807@colorado.edu>                                                    [IPython-dev] Re: iPython on Windows
# <200304291817.05898.Kasper.Souren@ircam.fr>                            [IPython-dev] possible feature request: auto-run
# <200304291817.05898.Kasper.Souren@ircam.fr>                            [IPython-dev] possible feature request: auto-run
# <3EAEF194.5030709@colorado.edu>                                        [IPython-dev] possible feature request: auto-run
# <3EAEF194.5030709@colorado.edu>                                        [IPython-dev] possible feature request: auto-run
# <200304292248.10994.Kasper.Souren@ircam.fr>                            [IPython-dev] possible feature request: auto-run
# <200304292248.10994.Kasper.Souren@ircam.fr>                            [IPython-dev] possible feature request: auto-run
# <CB0365D517B7D611B5E100508B9498B6022A9B50@erlh904a.med.siemens.de>    [IPython-dev] RE: [Fwd: [IPython-user] re: Fwd...
# <CB0365D517B7D611B5E100508B9498B6022A9B50@erlh904a.med.siemens.de>    [IPython-dev] RE: [Fwd: [IPython-user] re: Fwd...
# <200305121234.h4CCYmXo027167@wren.cs.unc.edu>                         [IPython-dev] RE: [Fwd: [IPython-user] re: Fwd...
# <200305121234.h4CCYmXo027167@wren.cs.unc.edu>                         [IPython-dev] RE: [Fwd: [IPython-user] re: Fwd...
# <3EC143D7.8050907@colorado.edu>                                                  [IPython-dev] Re: IPython Crash Report
# <3EC143D7.8050907@colorado.edu>                                                  [IPython-dev] Re: IPython Crash Report
# <200305171149.h4HBneXo024735@wren.cs.unc.edu>                                  [IPython-dev] re: 0.4.0 ready for Monday
# <200305171149.h4HBneXo024735@wren.cs.unc.edu>                                  [IPython-dev] re: 0.4.0 ready for Monday
# ...                                                                                                                 ...
# <CAGA_dmj2Mbf7wydpTX6wD=x7VmkBE+6efWC=5jC4pSPiQy0CnQ@mail.gmail.com>  [IPython-dev] Removing "Out[]" prompts in nbco...
# <CACejjWychJZv_QXsOx3iQ6CETt_hFXQVRW1eT3dYizjPVW8HSQ@mail.gmail.com>                  [IPython-dev] IHaskell on Jupyter
# <CAAusYCjPPDJvzhBazUk7kibW_OqeRVHNS2OykshHt+UOtzJYsw@mail.gmail.com>                  [IPython-dev] IHaskell on Jupyter
# <CADK4v1hPRXYLHucdNFLgN4U_LTbyfmb=+MEU6qrNwnmF9g9TiA@mail.gmail.com>  [IPython-dev] Kernels, located on the remote m...
# <095EA2AD-DC8B-4A0D-A8F3-61C2BD11B635@gmail.com>                       [IPython-dev] [jupyter] Re:  IHaskell on Jupyter
# <CACfEFw-DvqgS90by+kjB1AB20AU102=6PvZBzrqK20cT8j2r0Q@mail.gmail.com>  [IPython-dev] Kernels, located on the remote m...
# <D623C3FB-430A-42C7-8E2F-E7EDF7605EF2@gmail.com>                      [IPython-dev] Kernels, located on the remote m...
# <6CAE1ADC-853E-47CC-A5F4-AD43DEF33FB6@gmail.com>                      [IPython-dev] Kernels, located on the remote m...
# <CACfEFw9ryXo-0j3UzwmwHPfLriWqT2OMqGOdsrqptDSSUyB7ew@mail.gmail.com>  [IPython-dev] Kernels, located on the remote m...
# <551498E2.3060207@student.american.edu>                               [IPython-dev] Cannot connect to kernel when no...
# <CAOvn4qjSAYqZjy0uR6O4qMb3vY1VoOmR-rBVSEJ30TjsP==MAg@mail.gmail.com>  [IPython-dev] Cannot connect to kernel when no...
# <CADK4v1gDrJJQ+8gYA+biJuUpXnvXLJwfFjrsVMrwouDfsa7i3A@mail.gmail.com>  [IPython-dev] Kernels, located on the remote m...
# <5515689A.50509@student.american.edu>                                 [IPython-dev] Cannot connect to kernel when no...
# <55156CBC.6020908@student.american.edu>                               [IPython-dev] Cannot connect to kernel when no...
# <55160425.6070309@student.american.edu>                               [IPython-dev] Cannot connect to kernel when no...
# <CAH+mRR2OHcPt2ZCx3E5oBfX+suRjcbRhfrM1meqSadB2HDpUyQ@mail.gmail.com>   [IPython-dev] Deploying JupyterHub for Education
# <CAKxBDU_e6J5h2WAtEPCax+_gn5B_zk6oDmrhat1mPZFpUUfkNA@mail.gmail.com>  [IPython-dev] Controlling prioritization in IP...
# <CAGA_dmgWUVZNThwRL=w8yo+Ke7xgoV2N7h1oFqNLXE9-n2xVUQ@mail.gmail.com>  [IPython-dev] Removing "Out[]" prompts in nbco...
# <CAHAreOqyPxmA4kMiVxzBMH-fQPvx_Or-_dzB7nJuMbmdSy86Lg@mail.gmail.com>  [IPython-dev] Removing "Out[]" prompts in nbco...
# <CAHNn8BUQJu4iD71whEQuQAfk0=oCjrcwcR81ANoAGyO4ZYwUjA@mail.gmail.com>  [IPython-dev] Controlling prioritization in IP...
# <CAGA_dmgqF_uM3yUNSF3o4YTwa7f0w58mqOuM_+Y=TihJtO-iFw@mail.gmail.com>  [IPython-dev] Removing "Out[]" prompts in nbco...
# <CAHAreOq_DrcmuTQ=a2Yy3Ar=KGasMONDzB=zxP384q1sQjqeyA@mail.gmail.com>  [IPython-dev] Controlling prioritization in IP...
# <CAHAreOoT+0MD9eCfrpcW=iOj93JCVQeKjZ2TAQjzr8fOiMsVLw@mail.gmail.com>  [IPython-dev] Removing "Out[]" prompts in nbco...
# <CAHAreOoj7+62Qw3z4mnKuESyfxonCoJt6QeLgt-HZLMmiDzE+w@mail.gmail.com>  [IPython-dev] Welcoming Jessica Hamrick to the...
# <CAH4pYpTnB8SOtqu-tDXmrravfVvzzcaagTGks=jWHXHrK1Nipw@mail.gmail.com>  [IPython-dev] [jupyter] Welcoming Jessica Hamr...
# <CA+tbMaVCT5vN8kTEh64THqt9YcJWFuzDh=D-DMckwJvCe-pF9g@mail.gmail.com>  [IPython-dev] [jupyter] Welcoming Jessica Hamr...
# <CAH+mRR2B+QRqPxk8cZRCG7p6tFmRUWdCiWPMe+SkxEtwec6Jhg@mail.gmail.com>  [IPython-dev] [jupyter] Welcoming Jessica Hamr...
# <CANJQusWnqvjA+Jk-S6hF0Eo64GodkXPD80ne8dssW=L3g8jS+w@mail.gmail.com>  [IPython-dev] [jupyter] Welcoming Jessica Hamr...
# <CALUXcBwNPLP-_ZndrHtDQtJ4fBuBt-Uo1m2OFhUH_+zhZfQuNA@mail.gmail.com>  [IPython-dev] [jupyter] Welcoming Jessica Hamr...
# <CACejjWwWdJZ+NjVtn+Ao2yJCTvh+32oNEkLBwWW6Cyw+gYJSSA@mail.gmail.com>    [IPython-dev] [jupyter] Re: IHaskell on Jupyter
#
#                                                                                     Date  \
# Message-ID
# <3E9DE124.8080309@colorado.edu>                                      2003-04-16 23:03:00
# <3E9DE124.8080309@colorado.edu>                                      2003-04-16 23:03:00
# <3E9E4094.7030802@colorado.edu>                                      2003-04-17 05:50:12
# <3E9E4094.7030802@colorado.edu>                                      2003-04-17 05:50:12
# <000c01c304ee$3cb79e60$e901340a@cyberhigh.fcoe.k12.ca.us>            2003-04-17 14:32:56
# <000c01c304ee$3cb79e60$e901340a@cyberhigh.fcoe.k12.ca.us>            2003-04-17 14:32:56
# <3E9EC1CA.3060800@colorado.edu>                                      2003-04-17 15:01:30
# <3E9EC1CA.3060800@colorado.edu>                                      2003-04-17 15:01:30
# <3E9EF5E3.8080100@colorado.edu>                                      2003-04-17 18:43:47
# <3E9EF5E3.8080100@colorado.edu>                                      2003-04-17 18:43:47
# <3E9EFC95.7040309@colorado.edu>                                      2003-04-17 19:12:21
# <3E9EFC95.7040309@colorado.edu>                                      2003-04-17 19:12:21
# <3E9F3B79.7070005@colorado.edu>                                      2003-04-17 23:40:41
# <3E9F3B79.7070005@colorado.edu>                                      2003-04-17 23:40:41
# <3E9F3D9B.8040807@colorado.edu>                                      2003-04-17 23:49:47
# <3E9F3D9B.8040807@colorado.edu>                                      2003-04-17 23:49:47
# <200304291817.05898.Kasper.Souren@ircam.fr>                          2003-04-29 18:17:05
# <200304291817.05898.Kasper.Souren@ircam.fr>                          2003-04-29 18:17:05
# <3EAEF194.5030709@colorado.edu>                                      2003-04-29 21:41:40
# <3EAEF194.5030709@colorado.edu>                                      2003-04-29 21:41:40
# <200304292248.10994.Kasper.Souren@ircam.fr>                          2003-04-29 22:48:10
# <200304292248.10994.Kasper.Souren@ircam.fr>                          2003-04-29 22:48:10
# <CB0365D517B7D611B5E100508B9498B6022A9B50@erlh904a.med.siemens.de>   2003-05-12 07:28:55
# <CB0365D517B7D611B5E100508B9498B6022A9B50@erlh904a.med.siemens.de>   2003-05-12 07:28:55
# <200305121234.h4CCYmXo027167@wren.cs.unc.edu>                        2003-05-12 08:34:48
# <200305121234.h4CCYmXo027167@wren.cs.unc.edu>                        2003-05-12 08:34:48
# <3EC143D7.8050907@colorado.edu>                                      2003-05-13 19:13:27
# <3EC143D7.8050907@colorado.edu>                                      2003-05-13 19:13:27
# <200305171149.h4HBneXo024735@wren.cs.unc.edu>                        2003-05-17 07:49:39
# <200305171149.h4HBneXo024735@wren.cs.unc.edu>                        2003-05-17 07:49:39
# ...                                                                                  ...
# <CAGA_dmj2Mbf7wydpTX6wD=x7VmkBE+6efWC=5jC4pSPiQy0CnQ@mail.gmail.com> 2015-03-26 11:32:26
# <CACejjWychJZv_QXsOx3iQ6CETt_hFXQVRW1eT3dYizjPVW8HSQ@mail.gmail.com> 2015-03-26 12:30:37
# <CAAusYCjPPDJvzhBazUk7kibW_OqeRVHNS2OykshHt+UOtzJYsw@mail.gmail.com> 2015-03-26 13:00:55
# <CADK4v1hPRXYLHucdNFLgN4U_LTbyfmb=+MEU6qrNwnmF9g9TiA@mail.gmail.com> 2015-03-26 14:43:23
# <095EA2AD-DC8B-4A0D-A8F3-61C2BD11B635@gmail.com>                     2015-03-26 15:20:57
# <CACfEFw-DvqgS90by+kjB1AB20AU102=6PvZBzrqK20cT8j2r0Q@mail.gmail.com> 2015-03-26 15:24:24
# <D623C3FB-430A-42C7-8E2F-E7EDF7605EF2@gmail.com>                     2015-03-26 15:32:05
# <6CAE1ADC-853E-47CC-A5F4-AD43DEF33FB6@gmail.com>                     2015-03-26 15:33:29
# <CACfEFw9ryXo-0j3UzwmwHPfLriWqT2OMqGOdsrqptDSSUyB7ew@mail.gmail.com> 2015-03-26 15:52:57
# <551498E2.3060207@student.american.edu>                              2015-03-26 23:40:18
# <CAOvn4qjSAYqZjy0uR6O4qMb3vY1VoOmR-rBVSEJ30TjsP==MAg@mail.gmail.com> 2015-03-27 00:37:43
# <CADK4v1gDrJJQ+8gYA+biJuUpXnvXLJwfFjrsVMrwouDfsa7i3A@mail.gmail.com> 2015-03-27 13:59:40
# <5515689A.50509@student.american.edu>                                2015-03-27 14:26:34
# <55156CBC.6020908@student.american.edu>                              2015-03-27 14:44:12
# <55160425.6070309@student.american.edu>                              2015-03-28 01:30:13
# <CAH+mRR2OHcPt2ZCx3E5oBfX+suRjcbRhfrM1meqSadB2HDpUyQ@mail.gmail.com> 2015-03-28 13:11:59
# <CAKxBDU_e6J5h2WAtEPCax+_gn5B_zk6oDmrhat1mPZFpUUfkNA@mail.gmail.com> 2015-03-29 08:44:00
# <CAGA_dmgWUVZNThwRL=w8yo+Ke7xgoV2N7h1oFqNLXE9-n2xVUQ@mail.gmail.com> 2015-03-29 10:30:37
# <CAHAreOqyPxmA4kMiVxzBMH-fQPvx_Or-_dzB7nJuMbmdSy86Lg@mail.gmail.com> 2015-03-29 19:11:43
# <CAHNn8BUQJu4iD71whEQuQAfk0=oCjrcwcR81ANoAGyO4ZYwUjA@mail.gmail.com> 2015-03-29 20:12:13
# <CAGA_dmgqF_uM3yUNSF3o4YTwa7f0w58mqOuM_+Y=TihJtO-iFw@mail.gmail.com> 2015-03-29 21:23:27
# <CAHAreOq_DrcmuTQ=a2Yy3Ar=KGasMONDzB=zxP384q1sQjqeyA@mail.gmail.com> 2015-03-29 21:26:39
# <CAHAreOoT+0MD9eCfrpcW=iOj93JCVQeKjZ2TAQjzr8fOiMsVLw@mail.gmail.com> 2015-03-29 21:27:12
# <CAHAreOoj7+62Qw3z4mnKuESyfxonCoJt6QeLgt-HZLMmiDzE+w@mail.gmail.com> 2015-03-30 01:05:09
# <CAH4pYpTnB8SOtqu-tDXmrravfVvzzcaagTGks=jWHXHrK1Nipw@mail.gmail.com> 2015-03-30 01:14:30
# <CA+tbMaVCT5vN8kTEh64THqt9YcJWFuzDh=D-DMckwJvCe-pF9g@mail.gmail.com> 2015-03-30 01:16:03
# <CAH+mRR2B+QRqPxk8cZRCG7p6tFmRUWdCiWPMe+SkxEtwec6Jhg@mail.gmail.com> 2015-03-30 01:38:36
# <CANJQusWnqvjA+Jk-S6hF0Eo64GodkXPD80ne8dssW=L3g8jS+w@mail.gmail.com> 2015-03-30 01:58:11
# <CALUXcBwNPLP-_ZndrHtDQtJ4fBuBt-Uo1m2OFhUH_+zhZfQuNA@mail.gmail.com> 2015-03-30 13:45:00
# <CACejjWwWdJZ+NjVtn+Ao2yJCTvh+32oNEkLBwWW6Cyw+gYJSSA@mail.gmail.com> 2015-03-30 15:05:43
#
#                                                                                                             In-Reply-To  \
# Message-ID
# <3E9DE124.8080309@colorado.edu>                                                                                    None
# <3E9DE124.8080309@colorado.edu>                                                                                    None
# <3E9E4094.7030802@colorado.edu>                                       <003d01c28a9a$3dcb8560$e301340a@cyberhigh.fcoe...
# <3E9E4094.7030802@colorado.edu>                                       <003d01c28a9a$3dcb8560$e301340a@cyberhigh.fcoe...
# <000c01c304ee$3cb79e60$e901340a@cyberhigh.fcoe.k12.ca.us>                               <3E9E4094.7030802@colorado.edu>
# <000c01c304ee$3cb79e60$e901340a@cyberhigh.fcoe.k12.ca.us>                               <3E9E4094.7030802@colorado.edu>
# <3E9EC1CA.3060800@colorado.edu>                                       <000c01c304ee$3cb79e60$e901340a@cyberhigh.fcoe...
# <3E9EC1CA.3060800@colorado.edu>                                       <000c01c304ee$3cb79e60$e901340a@cyberhigh.fcoe...
# <3E9EF5E3.8080100@colorado.edu>                                                                                    None
# <3E9EF5E3.8080100@colorado.edu>                                                                                    None
# <3E9EFC95.7040309@colorado.edu>                                                                                    None
# <3E9EFC95.7040309@colorado.edu>                                                                                    None
# <3E9F3B79.7070005@colorado.edu>                                                                                    None
# <3E9F3B79.7070005@colorado.edu>                                                                                    None
# <3E9F3D9B.8040807@colorado.edu>                                           <GCEDKONBLEFPPADDJCOECEOIIPAA.whisper@oz.net>
# <3E9F3D9B.8040807@colorado.edu>                                           <GCEDKONBLEFPPADDJCOECEOIIPAA.whisper@oz.net>
# <200304291817.05898.Kasper.Souren@ircam.fr>                                                                        None
# <200304291817.05898.Kasper.Souren@ircam.fr>                                                                        None
# <3EAEF194.5030709@colorado.edu>                                             <200304291817.05898.Kasper.Souren@ircam.fr>
# <3EAEF194.5030709@colorado.edu>                                             <200304291817.05898.Kasper.Souren@ircam.fr>
# <200304292248.10994.Kasper.Souren@ircam.fr>                                             <3EAEF194.5030709@colorado.edu>
# <200304292248.10994.Kasper.Souren@ircam.fr>                                             <3EAEF194.5030709@colorado.edu>
# <CB0365D517B7D611B5E100508B9498B6022A9B50@erlh904a.med.siemens.de>                                                 None
# <CB0365D517B7D611B5E100508B9498B6022A9B50@erlh904a.med.siemens.de>                                                 None
# <200305121234.h4CCYmXo027167@wren.cs.unc.edu>                                                                      None
# <200305121234.h4CCYmXo027167@wren.cs.unc.edu>                                                                      None
# <3EC143D7.8050907@colorado.edu>                                           <200305131849.h4DInjXo018909@wren.cs.unc.edu>
# <3EC143D7.8050907@colorado.edu>                                           <200305131849.h4DInjXo018909@wren.cs.unc.edu>
# <200305171149.h4HBneXo024735@wren.cs.unc.edu>                                                                      None
# <200305171149.h4HBneXo024735@wren.cs.unc.edu>                                                                      None
# ...                                                                                                                 ...
# <CAGA_dmj2Mbf7wydpTX6wD=x7VmkBE+6efWC=5jC4pSPiQy0CnQ@mail.gmail.com>  <CAHzsXVXcZhDydAOT1+8dwgE2exDDRRd5DWO5XaOCXbPT...
# <CACejjWychJZv_QXsOx3iQ6CETt_hFXQVRW1eT3dYizjPVW8HSQ@mail.gmail.com>   <5AE8F615-C1AF-47DF-894F-98FD315934A5@gmail.com>
# <CAAusYCjPPDJvzhBazUk7kibW_OqeRVHNS2OykshHt+UOtzJYsw@mail.gmail.com>  <CACejjWychJZv_QXsOx3iQ6CETt_hFXQVRW1eT3dYizjP...
# <CADK4v1hPRXYLHucdNFLgN4U_LTbyfmb=+MEU6qrNwnmF9g9TiA@mail.gmail.com>                                               None
# <095EA2AD-DC8B-4A0D-A8F3-61C2BD11B635@gmail.com>                      <CAAusYCjPPDJvzhBazUk7kibW_OqeRVHNS2OykshHt+UO...
# <CACfEFw-DvqgS90by+kjB1AB20AU102=6PvZBzrqK20cT8j2r0Q@mail.gmail.com>  <CADK4v1hPRXYLHucdNFLgN4U_LTbyfmb=+MEU6qrNwnmF...
# <D623C3FB-430A-42C7-8E2F-E7EDF7605EF2@gmail.com>                      <CADK4v1hPRXYLHucdNFLgN4U_LTbyfmb=+MEU6qrNwnmF...
# <6CAE1ADC-853E-47CC-A5F4-AD43DEF33FB6@gmail.com>                      <CACfEFw-DvqgS90by+kjB1AB20AU102=6PvZBzrqK20cT...
# <CACfEFw9ryXo-0j3UzwmwHPfLriWqT2OMqGOdsrqptDSSUyB7ew@mail.gmail.com>   <6CAE1ADC-853E-47CC-A5F4-AD43DEF33FB6@gmail.com>
# <551498E2.3060207@student.american.edu>                               <CACfEFw9ryXo-0j3UzwmwHPfLriWqT2OMqGOdsrqptDSS...
# <CAOvn4qjSAYqZjy0uR6O4qMb3vY1VoOmR-rBVSEJ30TjsP==MAg@mail.gmail.com>            <551498E2.3060207@student.american.edu>
# <CADK4v1gDrJJQ+8gYA+biJuUpXnvXLJwfFjrsVMrwouDfsa7i3A@mail.gmail.com>                                               None
# <5515689A.50509@student.american.edu>                                 <CAOvn4qjSAYqZjy0uR6O4qMb3vY1VoOmR-rBVSEJ30Tjs...
# <55156CBC.6020908@student.american.edu>                               <CAOvn4qjSAYqZjy0uR6O4qMb3vY1VoOmR-rBVSEJ30Tjs...
# <55160425.6070309@student.american.edu>                                         <55156CBC.6020908@student.american.edu>
# <CAH+mRR2OHcPt2ZCx3E5oBfX+suRjcbRhfrM1meqSadB2HDpUyQ@mail.gmail.com>  <CAH4pYpQU=5ApgPgpaPFZ7YtbNw_8w8TMBATcHTgmDA0j...
# <CAKxBDU_e6J5h2WAtEPCax+_gn5B_zk6oDmrhat1mPZFpUUfkNA@mail.gmail.com>                                               None
# <CAGA_dmgWUVZNThwRL=w8yo+Ke7xgoV2N7h1oFqNLXE9-n2xVUQ@mail.gmail.com>  <CAGA_dmj2Mbf7wydpTX6wD=x7VmkBE+6efWC=5jC4pSPi...
# <CAHAreOqyPxmA4kMiVxzBMH-fQPvx_Or-_dzB7nJuMbmdSy86Lg@mail.gmail.com>  <CAGA_dmgWUVZNThwRL=w8yo+Ke7xgoV2N7h1oFqNLXE9-...
# <CAHNn8BUQJu4iD71whEQuQAfk0=oCjrcwcR81ANoAGyO4ZYwUjA@mail.gmail.com>  <CAKxBDU_e6J5h2WAtEPCax+_gn5B_zk6oDmrhat1mPZFp...
# <CAGA_dmgqF_uM3yUNSF3o4YTwa7f0w58mqOuM_+Y=TihJtO-iFw@mail.gmail.com>  <CAHAreOqyPxmA4kMiVxzBMH-fQPvx_Or-_dzB7nJuMbmd...
# <CAHAreOq_DrcmuTQ=a2Yy3Ar=KGasMONDzB=zxP384q1sQjqeyA@mail.gmail.com>  <CAHNn8BUQJu4iD71whEQuQAfk0=oCjrcwcR81ANoAGyO4...
# <CAHAreOoT+0MD9eCfrpcW=iOj93JCVQeKjZ2TAQjzr8fOiMsVLw@mail.gmail.com>  <CAGA_dmgqF_uM3yUNSF3o4YTwa7f0w58mqOuM_+Y=TihJ...
# <CAHAreOoj7+62Qw3z4mnKuESyfxonCoJt6QeLgt-HZLMmiDzE+w@mail.gmail.com>                                               None
# <CAH4pYpTnB8SOtqu-tDXmrravfVvzzcaagTGks=jWHXHrK1Nipw@mail.gmail.com>  <CAHAreOoj7+62Qw3z4mnKuESyfxonCoJt6QeLgt-HZLMm...
# <CA+tbMaVCT5vN8kTEh64THqt9YcJWFuzDh=D-DMckwJvCe-pF9g@mail.gmail.com>  <CAH4pYpTnB8SOtqu-tDXmrravfVvzzcaagTGks=jWHXHr...
# <CAH+mRR2B+QRqPxk8cZRCG7p6tFmRUWdCiWPMe+SkxEtwec6Jhg@mail.gmail.com>  <CA+tbMaVCT5vN8kTEh64THqt9YcJWFuzDh=D-DMckwJvC...
# <CANJQusWnqvjA+Jk-S6hF0Eo64GodkXPD80ne8dssW=L3g8jS+w@mail.gmail.com>  <CAH+mRR2B+QRqPxk8cZRCG7p6tFmRUWdCiWPMe+SkxEtw...
# <CALUXcBwNPLP-_ZndrHtDQtJ4fBuBt-Uo1m2OFhUH_+zhZfQuNA@mail.gmail.com>  <CANJQusWnqvjA+Jk-S6hF0Eo64GodkXPD80ne8dssW=L3...
# <CACejjWwWdJZ+NjVtn+Ao2yJCTvh+32oNEkLBwWW6Cyw+gYJSSA@mail.gmail.com>   <095EA2AD-DC8B-4A0D-A8F3-61C2BD11B635@gmail.com>
#
#                                                                                                              References  \
# Message-ID
# <3E9DE124.8080309@colorado.edu>                                                                                    None
# <3E9DE124.8080309@colorado.edu>                                                                                    None
# <3E9E4094.7030802@colorado.edu>                                       <003d01c28a9a$3dcb8560$e301340a@cyberhigh.fcoe...
# <3E9E4094.7030802@colorado.edu>                                       <003d01c28a9a$3dcb8560$e301340a@cyberhigh.fcoe...
# <000c01c304ee$3cb79e60$e901340a@cyberhigh.fcoe.k12.ca.us>                                                          None
# <000c01c304ee$3cb79e60$e901340a@cyberhigh.fcoe.k12.ca.us>                                                          None
# <3E9EC1CA.3060800@colorado.edu>                                       <000c01c304ee$3cb79e60$e901340a@cyberhigh.fcoe...
# <3E9EC1CA.3060800@colorado.edu>                                       <000c01c304ee$3cb79e60$e901340a@cyberhigh.fcoe...
# <3E9EF5E3.8080100@colorado.edu>                                                                                    None
# <3E9EF5E3.8080100@colorado.edu>                                                                                    None
# <3E9EFC95.7040309@colorado.edu>                                                                                    None
# <3E9EFC95.7040309@colorado.edu>                                                                                    None
# <3E9F3B79.7070005@colorado.edu>                                                                                    None
# <3E9F3B79.7070005@colorado.edu>                                                                                    None
# <3E9F3D9B.8040807@colorado.edu>                                           <GCEDKONBLEFPPADDJCOECEOIIPAA.whisper@oz.net>
# <3E9F3D9B.8040807@colorado.edu>                                           <GCEDKONBLEFPPADDJCOECEOIIPAA.whisper@oz.net>
# <200304291817.05898.Kasper.Souren@ircam.fr>                                                                        None
# <200304291817.05898.Kasper.Souren@ircam.fr>                                                                        None
# <3EAEF194.5030709@colorado.edu>                                             <200304291817.05898.Kasper.Souren@ircam.fr>
# <3EAEF194.5030709@colorado.edu>                                             <200304291817.05898.Kasper.Souren@ircam.fr>
# <200304292248.10994.Kasper.Souren@ircam.fr>                           <200304291817.05898.Kasper.Souren@ircam.fr> <3...
# <200304292248.10994.Kasper.Souren@ircam.fr>                           <200304291817.05898.Kasper.Souren@ircam.fr> <3...
# <CB0365D517B7D611B5E100508B9498B6022A9B50@erlh904a.med.siemens.de>                                                 None
# <CB0365D517B7D611B5E100508B9498B6022A9B50@erlh904a.med.siemens.de>                                                 None
# <200305121234.h4CCYmXo027167@wren.cs.unc.edu>                                                                      None
# <200305121234.h4CCYmXo027167@wren.cs.unc.edu>                                                                      None
# <3EC143D7.8050907@colorado.edu>                                           <200305131849.h4DInjXo018909@wren.cs.unc.edu>
# <3EC143D7.8050907@colorado.edu>                                           <200305131849.h4DInjXo018909@wren.cs.unc.edu>
# <200305171149.h4HBneXo024735@wren.cs.unc.edu>                                                                      None
# <200305171149.h4HBneXo024735@wren.cs.unc.edu>                                                                      None
# ...                                                                                                                 ...
# <CAGA_dmj2Mbf7wydpTX6wD=x7VmkBE+6efWC=5jC4pSPiQy0CnQ@mail.gmail.com>  <CAGA_dmhcbH97xE-ei1pXhgL5=dow64rronG-fQuBA7LD...
# <CACejjWychJZv_QXsOx3iQ6CETt_hFXQVRW1eT3dYizjPVW8HSQ@mail.gmail.com>  <CAF-LYK+Lr-KT4AuvJubOjk3=7coV6Z+N7j3jNvdy8BGF...
# <CAAusYCjPPDJvzhBazUk7kibW_OqeRVHNS2OykshHt+UOtzJYsw@mail.gmail.com>  <CAF-LYK+Lr-KT4AuvJubOjk3=7coV6Z+N7j3jNvdy8BGF...
# <CADK4v1hPRXYLHucdNFLgN4U_LTbyfmb=+MEU6qrNwnmF9g9TiA@mail.gmail.com>                                               None
# <095EA2AD-DC8B-4A0D-A8F3-61C2BD11B635@gmail.com>                      <CAF-LYK+Lr-KT4AuvJubOjk3=7coV6Z+N7j3jNvdy8BGF...
# <CACfEFw-DvqgS90by+kjB1AB20AU102=6PvZBzrqK20cT8j2r0Q@mail.gmail.com>  <CADK4v1hPRXYLHucdNFLgN4U_LTbyfmb=+MEU6qrNwnmF...
# <D623C3FB-430A-42C7-8E2F-E7EDF7605EF2@gmail.com>                      <CADK4v1hPRXYLHucdNFLgN4U_LTbyfmb=+MEU6qrNwnmF...
# <6CAE1ADC-853E-47CC-A5F4-AD43DEF33FB6@gmail.com>                      <CADK4v1hPRXYLHucdNFLgN4U_LTbyfmb=+MEU6qrNwnmF...
# <CACfEFw9ryXo-0j3UzwmwHPfLriWqT2OMqGOdsrqptDSSUyB7ew@mail.gmail.com>  <CADK4v1hPRXYLHucdNFLgN4U_LTbyfmb=+MEU6qrNwnmF...
# <551498E2.3060207@student.american.edu>                               <CADK4v1hPRXYLHucdNFLgN4U_LTbyfmb=+MEU6qrNwnmF...
# <CAOvn4qjSAYqZjy0uR6O4qMb3vY1VoOmR-rBVSEJ30TjsP==MAg@mail.gmail.com>  <CADK4v1hPRXYLHucdNFLgN4U_LTbyfmb=+MEU6qrNwnmF...
# <CADK4v1gDrJJQ+8gYA+biJuUpXnvXLJwfFjrsVMrwouDfsa7i3A@mail.gmail.com>                                               None
# <5515689A.50509@student.american.edu>                                 <CADK4v1hPRXYLHucdNFLgN4U_LTbyfmb=+MEU6qrNwnmF...
# <55156CBC.6020908@student.american.edu>                               <CADK4v1hPRXYLHucdNFLgN4U_LTbyfmb=+MEU6qrNwnmF...
# <55160425.6070309@student.american.edu>                               <CADK4v1hPRXYLHucdNFLgN4U_LTbyfmb=+MEU6qrNwnmF...
# <CAH+mRR2OHcPt2ZCx3E5oBfX+suRjcbRhfrM1meqSadB2HDpUyQ@mail.gmail.com>  <CALUXcBygSskzJf-zAMPhmMrNfmxWARtBk0ZPMN-5YF5Y...
# <CAKxBDU_e6J5h2WAtEPCax+_gn5B_zk6oDmrhat1mPZFpUUfkNA@mail.gmail.com>                                               None
# <CAGA_dmgWUVZNThwRL=w8yo+Ke7xgoV2N7h1oFqNLXE9-n2xVUQ@mail.gmail.com>  <CAGA_dmhcbH97xE-ei1pXhgL5=dow64rronG-fQuBA7LD...
# <CAHAreOqyPxmA4kMiVxzBMH-fQPvx_Or-_dzB7nJuMbmdSy86Lg@mail.gmail.com>  <CAGA_dmhcbH97xE-ei1pXhgL5=dow64rronG-fQuBA7LD...
# <CAHNn8BUQJu4iD71whEQuQAfk0=oCjrcwcR81ANoAGyO4ZYwUjA@mail.gmail.com>  <CAKxBDU_e6J5h2WAtEPCax+_gn5B_zk6oDmrhat1mPZFp...
# <CAGA_dmgqF_uM3yUNSF3o4YTwa7f0w58mqOuM_+Y=TihJtO-iFw@mail.gmail.com>  <CAGA_dmhcbH97xE-ei1pXhgL5=dow64rronG-fQuBA7LD...
# <CAHAreOq_DrcmuTQ=a2Yy3Ar=KGasMONDzB=zxP384q1sQjqeyA@mail.gmail.com>  <CAKxBDU_e6J5h2WAtEPCax+_gn5B_zk6oDmrhat1mPZFp...
# <CAHAreOoT+0MD9eCfrpcW=iOj93JCVQeKjZ2TAQjzr8fOiMsVLw@mail.gmail.com>  <CAGA_dmhcbH97xE-ei1pXhgL5=dow64rronG-fQuBA7LD...
# <CAHAreOoj7+62Qw3z4mnKuESyfxonCoJt6QeLgt-HZLMmiDzE+w@mail.gmail.com>                                               None
# <CAH4pYpTnB8SOtqu-tDXmrravfVvzzcaagTGks=jWHXHrK1Nipw@mail.gmail.com>  <CAHAreOoj7+62Qw3z4mnKuESyfxonCoJt6QeLgt-HZLMm...
# <CA+tbMaVCT5vN8kTEh64THqt9YcJWFuzDh=D-DMckwJvCe-pF9g@mail.gmail.com>  <CAHAreOoj7+62Qw3z4mnKuESyfxonCoJt6QeLgt-HZLMm...
# <CAH+mRR2B+QRqPxk8cZRCG7p6tFmRUWdCiWPMe+SkxEtwec6Jhg@mail.gmail.com>  <CAHAreOoj7+62Qw3z4mnKuESyfxonCoJt6QeLgt-HZLMm...
# <CANJQusWnqvjA+Jk-S6hF0Eo64GodkXPD80ne8dssW=L3g8jS+w@mail.gmail.com>  <CAHAreOoj7+62Qw3z4mnKuESyfxonCoJt6QeLgt-HZLMm...
# <CALUXcBwNPLP-_ZndrHtDQtJ4fBuBt-Uo1m2OFhUH_+zhZfQuNA@mail.gmail.com>  <CAHAreOoj7+62Qw3z4mnKuESyfxonCoJt6QeLgt-HZLMm...
# <CACejjWwWdJZ+NjVtn+Ao2yJCTvh+32oNEkLBwWW6Cyw+gYJSSA@mail.gmail.com>  <CAF-LYK+Lr-KT4AuvJubOjk3=7coV6Z+N7j3jNvdy8BGF...
#
#                                                                                                                    Body
# Message-ID
# <3E9DE124.8080309@colorado.edu>                                       Hi all,\n\nafter a suggestion by Jacek Generow...
# <3E9DE124.8080309@colorado.edu>                                       Hi all,\n\nafter a suggestion by Jacek Generow...
# <3E9E4094.7030802@colorado.edu>                                       Hi Cory,\n\n> Done.  install command will now ...
# <3E9E4094.7030802@colorado.edu>                                       Hi Cory,\n\n> Done.  install command will now ...
# <000c01c304ee$3cb79e60$e901340a@cyberhigh.fcoe.k12.ca.us>             Distutils 1.0.3 is not included with Python 2....
# <000c01c304ee$3cb79e60$e901340a@cyberhigh.fcoe.k12.ca.us>             Distutils 1.0.3 is not included with Python 2....
# <3E9EC1CA.3060800@colorado.edu>                                       Cory Dodt wrote:\n> Distutils 1.0.3 is not inc...
# <3E9EC1CA.3060800@colorado.edu>                                       Cory Dodt wrote:\n> Distutils 1.0.3 is not inc...
# <3E9EF5E3.8080100@colorado.edu>                                       Hi all,\n\nI've just put out a new pre-release...
# <3E9EF5E3.8080100@colorado.edu>                                       Hi all,\n\nI've just put out a new pre-release...
# <3E9EFC95.7040309@colorado.edu>                                       Hi all,\n\nI'd like to put out a list of thing...
# <3E9EFC95.7040309@colorado.edu>                                       Hi all,\n\nI'd like to put out a list of thing...
# <3E9F3B79.7070005@colorado.edu>                                       Hi all,\n\nI just wanted to let you know that,...
# <3E9F3B79.7070005@colorado.edu>                                       Hi all,\n\nI just wanted to let you know that,...
# <3E9F3D9B.8040807@colorado.edu>                                       Hi David,\n\nmy apologies for the long delay i...
# <3E9F3D9B.8040807@colorado.edu>                                       Hi David,\n\nmy apologies for the long delay i...
# <200304291817.05898.Kasper.Souren@ircam.fr>                           Hi!\n\nI just had a little idea for a new IPyt...
# <200304291817.05898.Kasper.Souren@ircam.fr>                           Hi!\n\nI just had a little idea for a new IPyt...
# <3EAEF194.5030709@colorado.edu>                                       Kasper Souren wrote:\n> Hi!\n> \n> I just had ...
# <3EAEF194.5030709@colorado.edu>                                       Kasper Souren wrote:\n> Hi!\n> \n> I just had ...
# <200304292248.10994.Kasper.Souren@ircam.fr>                           > It's rather complicated to get it right, and...
# <200304292248.10994.Kasper.Souren@ircam.fr>                           > It's rather complicated to get it right, and...
# <CB0365D517B7D611B5E100508B9498B6022A9B50@erlh904a.med.siemens.de>    Dear List,\n\nI'm working with IPython since a...
# <CB0365D517B7D611B5E100508B9498B6022A9B50@erlh904a.med.siemens.de>    Dear List,\n\nI'm working with IPython since a...
# <200305121234.h4CCYmXo027167@wren.cs.unc.edu>                         Thanks Chris,\n\nWith that hint and some googl...
# <200305121234.h4CCYmXo027167@wren.cs.unc.edu>                         Thanks Chris,\n\nWith that hint and some googl...
# <3EC143D7.8050907@colorado.edu>                                       Hi Gary,\n\n> The idea is simple. I assume tha...
# <3EC143D7.8050907@colorado.edu>                                       Hi Gary,\n\n> The idea is simple. I assume tha...
# <200305171149.h4HBneXo024735@wren.cs.unc.edu>                         It still says it is 0.2.15.pre5, I guess that ...
# <200305171149.h4HBneXo024735@wren.cs.unc.edu>                         It still says it is 0.2.15.pre5, I guess that ...
# ...                                                                                                                 ...
# <CAGA_dmj2Mbf7wydpTX6wD=x7VmkBE+6efWC=5jC4pSPiQy0CnQ@mail.gmail.com>  Hi Aaron,\n\nThanks a lot for your suggestion!...
# <CACejjWychJZv_QXsOx3iQ6CETt_hFXQVRW1eT3dYizjPVW8HSQ@mail.gmail.com>  Congrats!\n\nWhat is the PR (repo, requirement...
# <CAAusYCjPPDJvzhBazUk7kibW_OqeRVHNS2OykshHt+UOtzJYsw@mail.gmail.com>  On Thu, Mar 26, 2015 at 8:30 AM, Nicholas Boll...
# <CADK4v1hPRXYLHucdNFLgN4U_LTbyfmb=+MEU6qrNwnmF9g9TiA@mail.gmail.com>  Hi all,\n\nI'm trying to solve the task of *ad...
# <095EA2AD-DC8B-4A0D-A8F3-61C2BD11B635@gmail.com>                      Le 26 mars 2015 ? 06:00, Doug Blank <doug.blan...
# <CACfEFw-DvqgS90by+kjB1AB20AU102=6PvZBzrqK20cT8j2r0Q@mail.gmail.com>  Are there documentation and source links for t...
# <D623C3FB-430A-42C7-8E2F-E7EDF7605EF2@gmail.com>                      Hi, \n\nLe 26 mars 2015 ? 07:43, Ruslan Kornii...
# <6CAE1ADC-853E-47CC-A5F4-AD43DEF33FB6@gmail.com>                      Le 26 mars 2015 ? 08:24, Wes Turner <wes.turne...
# <CACfEFw9ryXo-0j3UzwmwHPfLriWqT2OMqGOdsrqptDSSUyB7ew@mail.gmail.com>  IPython Documentation and Source Links\n\n* BL...
# <551498E2.3060207@student.american.edu>                               Hello list,\n\nI recently explored setting up ...
# <CAOvn4qjSAYqZjy0uR6O4qMb3vY1VoOmR-rBVSEJ30TjsP==MAg@mail.gmail.com>  On 26 March 2015 at 16:40, Justin <jg3705a@stu...
# <CADK4v1gDrJJQ+8gYA+biJuUpXnvXLJwfFjrsVMrwouDfsa7i3A@mail.gmail.com>  Hi everyone,\n\nPersonal thanks to Matthias fo...
# <5515689A.50509@student.american.edu>                                 On 03/26/2015 05:37 PM, Thomas Kluyver wrote:\...
# <55156CBC.6020908@student.american.edu>                               Ok, I got it to work.\n\nIn case anyone else i...
# <55160425.6070309@student.american.edu>                               On 03/27/2015 07:44 AM, Justin wrote:\n> Ok, I...
# <CAH+mRR2OHcPt2ZCx3E5oBfX+suRjcbRhfrM1meqSadB2HDpUyQ@mail.gmail.com>  Thanks for sharing your experience with all of...
# <CAKxBDU_e6J5h2WAtEPCax+_gn5B_zk6oDmrhat1mPZFpUUfkNA@mail.gmail.com>  Can one specify any sort of prioritization to ...
# <CAGA_dmgWUVZNThwRL=w8yo+Ke7xgoV2N7h1oFqNLXE9-n2xVUQ@mail.gmail.com>  Ok, I had time to look a bit more into this an...
# <CAHAreOqyPxmA4kMiVxzBMH-fQPvx_Or-_dzB7nJuMbmdSy86Lg@mail.gmail.com>  On Sun, Mar 29, 2015 at 3:30 AM, Maximilian Al...
# <CAHNn8BUQJu4iD71whEQuQAfk0=oCjrcwcR81ANoAGyO4ZYwUjA@mail.gmail.com>  IPython.parallel currently has no support for ...
# <CAGA_dmgqF_uM3yUNSF3o4YTwa7f0w58mqOuM_+Y=TihJtO-iFw@mail.gmail.com>  2015-03-29 20:11 GMT+01:00 Fernando Perez <fpe...
# <CAHAreOq_DrcmuTQ=a2Yy3Ar=KGasMONDzB=zxP384q1sQjqeyA@mail.gmail.com>  On Sun, Mar 29, 2015 at 1:12 PM, MinRK <benjam...
# <CAHAreOoT+0MD9eCfrpcW=iOj93JCVQeKjZ2TAQjzr8fOiMsVLw@mail.gmail.com>  On Sun, Mar 29, 2015 at 2:23 PM, Maximilian Al...
# <CAHAreOoj7+62Qw3z4mnKuESyfxonCoJt6QeLgt-HZLMmiDzE+w@mail.gmail.com>  Hi all,\n\nI'd like to welcome Jess to the Ste...
# <CAH4pYpTnB8SOtqu-tDXmrravfVvzzcaagTGks=jWHXHrK1Nipw@mail.gmail.com>  Congrats Jess! This is well deserved!\n\nCheer...
# <CA+tbMaVCT5vN8kTEh64THqt9YcJWFuzDh=D-DMckwJvCe-pF9g@mail.gmail.com>  Congrats Jess! Great to have you!\n\n-- Kyle\n...
# <CAH+mRR2B+QRqPxk8cZRCG7p6tFmRUWdCiWPMe+SkxEtwec6Jhg@mail.gmail.com>  Congratulations! Jess!\nNice to have you on bo...
# <CANJQusWnqvjA+Jk-S6hF0Eo64GodkXPD80ne8dssW=L3g8jS+w@mail.gmail.com>  Congratulation to you Jess,\n\nYou are a worth...
# <CALUXcBwNPLP-_ZndrHtDQtJ4fBuBt-Uo1m2OFhUH_+zhZfQuNA@mail.gmail.com>  Thanks, everyone! I'm super psyched to be part...
# <CACejjWwWdJZ+NjVtn+Ao2yJCTvh+32oNEkLBwWW6Cyw+gYJSSA@mail.gmail.com>  Sounding good.\n\nI had a look at docker-demo-...
#
# [15485 rows x 6 columns]
